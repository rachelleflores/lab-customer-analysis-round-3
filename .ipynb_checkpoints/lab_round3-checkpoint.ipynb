# %% [markdown]
# # Lab | Customer Analysis Round 2 (Edited) and Round 3 (Below)

# %%
# import libraries
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# load csv file
df1 = pd.read_csv('files_for_lab/csv_files/marketing_customer_analysis.csv')

# %% [markdown]
# ## EXERCISES:

# %% [markdown]
# ### 1. Show the dataframe shape.

# %%
# number of rows and columns
df1.shape
# Out:
# (9134, 24)

# %% [markdown]
# ### 2. Standardize header names.

# %%
df1.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Response', 'Coverage',
#        'Education', 'Effective To Date', 'EmploymentStatus', 'Gender',
#        'Income', 'Location Code', 'Marital Status', 'Monthly Premium Auto',
#        'Months Since Last Claim', 'Months Since Policy Inception',
#        'Number of Open Complaints', 'Number of Policies', 'Policy Type',
#        'Policy', 'Renew Offer Type', 'Sales Channel', 'Total Claim Amount',
#        'Vehicle Class', 'Vehicle Size'],
#       dtype='object')

# %%
def standard_cols(dataframe):
    '''Standardize column names into lowercase and replace spaces with underscore.'''
    dataframe.columns = [col.lower().replace(' ','_') for col in df1.columns]
standard_cols(df1)
df1.head()
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   effective_to_date employmentstatus gender  income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   months_since_policy_inception number_of_open_complaints  number_of_policies  \
# 0                             5                         0                   1
# 1                            42                         0                   8
# 2                            38                         0                   2
# 3                            65                         0                   7
# 4                            44                         0                   1
#
#       policy_type        policy  renew_offer_type  sales_channel  \
# 0  Corporate Auto  Corporate L3            Offer1          Agent
# 1   Personal Auto   Personal L3            Offer3          Agent
# 2   Personal Auto   Personal L3            Offer1          Agent
# 3  Corporate Auto  Corporate L2            Offer1    Call Center
# 4   Personal Auto   Personal L1            Offer1          Agent
#
#   total_claim_amount  vehicle_class vehicle_size
# 0         384.811147   Two-Door Car      Medsize
# 1        1131.464935  Four-Door Car      Medsize
# 2         566.472247   Two-Door Car      Medsize
# 3         529.881344            SUV      Medsize
# 4         138.130879  Four-Door Car      Medsize
#
# [5 rows x 24 columns]

# %%
#df1 = df1.drop('unnamed:_0', axis=1) #dropping column which is has the same values as the index

# %% [markdown]
# ### 3/4. Numerical and Categorical Columns

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       9134 non-null   object
#  1   state                          9134 non-null   object
#  2   customer_lifetime_value        9134 non-null   float64
#  3   response                       9134 non-null   object
#  4   coverage                       9134 non-null   object
#  5   education                      9134 non-null   object
#  6   effective_to_date              9134 non-null   object
#  7   employmentstatus               9134 non-null   object
#  8   gender                         9134 non-null   object
#  9   income                         9134 non-null   int64
#  10  location_code                  9134 non-null   object
#  11  marital_status                 9134 non-null   object
#  12  monthly_premium_auto           9134 non-null   int64
#  13  months_since_last_claim        9134 non-null   int64
#  14  months_since_policy_inception  9134 non-null   int64
#  15  number_of_open_complaints      9134 non-null   int64
#  16  number_of_policies             9134 non-null   int64
#  17  policy_type                    9134 non-null   object
#  18  policy                         9134 non-null   object
#  19  renew_offer_type               9134 non-null   object
#  20  sales_channel                  9134 non-null   object
#  21  total_claim_amount             9134 non-null   float64
#  22  vehicle_class                  9134 non-null   object
#  23  vehicle_size                   9134 non-null   object
# dtypes: float64(2), int64(6), object(16)
# memory usage: 1.7+ MB

# %% [markdown]
# #### Numerical Variables

# %% [markdown]
# 1. customer_lifetime_value
# 2. months_since_last_claim
# 3. income
# 4. monthly_premium_auto
# 5. months_since_policy_inception
# 6. number_of_open_complaints
# 7. number_of_policies
# 8. total_claim_amount

# %% [markdown]
# #### Categorical Variables

# %% [markdown]
# 1. customer
# 2. state
# 3. response
# 4. coverage
# 5. education
# 6. effective_to_date
# 7. employmentstatus
# 8. gender
# 9. location_code
# 10. marital_status
# 11. policy_type
# 12. policy
# 13. renew_offer_type
# 14. sales_channel
# 15. vehicle_class
# 16. vehicle_size
# 17. vehicle_type (dropped)

# %% [markdown]
# ### Data Cleaning and Observation

# %%
# Dealing with duplicates
df1.duplicated().value_counts()
df2 = df1.drop_duplicates()

# %%
#df2.vehicle_type.value_counts(dropna=False)

# %%
#deciding to drop the vehicle_type column since there is only 1 unique value available and more than 50% is NaN
#variable is also very vague and not helpful
#df2 = df2.drop('vehicle_type', axis=1)

# %%
df2.head()
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   effective_to_date employmentstatus gender  income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   months_since_policy_inception number_of_open_complaints  number_of_policies  \
# 0                             5                         0                   1
# 1                            42                         0                   8
# 2                            38                         0                   2
# 3                            65                         0                   7
# 4                            44                         0                   1
#
#       policy_type        policy  renew_offer_type  sales_channel  \
# 0  Corporate Auto  Corporate L3            Offer1          Agent
# 1   Personal Auto   Personal L3            Offer3          Agent
# 2   Personal Auto   Personal L3            Offer1          Agent
# 3  Corporate Auto  Corporate L2            Offer1    Call Center
# 4   Personal Auto   Personal L1            Offer1          Agent
#
#   total_claim_amount  vehicle_class vehicle_size
# 0         384.811147   Two-Door Car      Medsize
# 1        1131.464935  Four-Door Car      Medsize
# 2         566.472247   Two-Door Car      Medsize
# 3         529.881344            SUV      Medsize
# 4         138.130879  Four-Door Car      Medsize
#
# [5 rows x 24 columns]

# %%
#Rounding off to 2 decimal places
df2.customer_lifetime_value = round(df2.customer_lifetime_value,2)
df2.total_claim_amount = round(df2.total_claim_amount,2)

# %%
df2['gender'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df2['vehicle_class'].unique()
# Out:
# array(['Two-Door Car', 'Four-Door Car', 'SUV', 'Luxury SUV', 'Sports Car',
#        'Luxury Car'], dtype=object)

# %%
df2['vehicle_size'].unique()
# Out:
# array(['Medsize', 'Small', 'Large'], dtype=object)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       9134 non-null   object
#  1   state                          9134 non-null   object
#  2   customer_lifetime_value        9134 non-null   float64
#  3   response                       9134 non-null   object
#  4   coverage                       9134 non-null   object
#  5   education                      9134 non-null   object
#  6   effective_to_date              9134 non-null   object
#  7   employmentstatus               9134 non-null   object
#  8   gender                         9134 non-null   object
#  9   income                         9134 non-null   int64
#  10  location_code                  9134 non-null   object
#  11  marital_status                 9134 non-null   object
#  12  monthly_premium_auto           9134 non-null   int64
#  13  months_since_last_claim        9134 non-null   int64
#  14  months_since_policy_inception  9134 non-null   int64
#  15  number_of_open_complaints      9134 non-null   int64
#  16  number_of_policies             9134 non-null   int64
#  17  policy_type                    9134 non-null   object
#  18  policy                         9134 non-null   object
#  19  renew_offer_type               9134 non-null   object
#  20  sales_channel                  9134 non-null   object
#  21  total_claim_amount             9134 non-null   float64
#  22  vehicle_class                  9134 non-null   object
#  23  vehicle_size                   9134 non-null   object
# dtypes: float64(2), int64(6), object(16)
# memory usage: 1.7+ MB

# %% [markdown]
# ### 5. Check and deal with NaN values.

# %%
df3 = df2 #copy dataframe for as safety precaution before starting to deal with null values

# %%
def check_na(dataframe):
    '''This function uses the dataframe as a parameter to check whether it has any null values.'''
    return dataframe.isna().sum()
check_na(df3)
# Out:
# customer                         0
# state                            0
# customer_lifetime_value          0
# response                         0
# coverage                         0
# education                        0
# effective_to_date                0
# employmentstatus                 0
# gender                           0
# income                           0
# location_code                    0
# marital_status                   0
# monthly_premium_auto             0
# months_since_last_claim          0
# months_since_policy_inception    0
# number_of_open_complaints        0
# number_of_policies               0
# policy_type                      0
# policy                           0
# renew_offer_type                 0
# sales_channel                    0
# total_claim_amount               0
# vehicle_class                    0
# vehicle_size                     0
# dtype: int64

# %%
plt.figure(figsize=(15,5))
corr_na = df3.isna().corr()
mask = np.zeros_like(corr_na)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(corr_na,annot=True, cmap='rocket_r',mask=mask)
# Out:
# /Users/RachelleFlores/opt/anaconda3/lib/python3.9/site-packages/seaborn/matrix.py:198: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# /Users/RachelleFlores/opt/anaconda3/lib/python3.9/site-packages/seaborn/matrix.py:203: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)
# <AxesSubplot:>

# %% [markdown]
# Missing Values Correlation = 1
# - state & response
# - months_since_last_claim & number_of_open_complaints
# - vehicle_class & vehicle_size

# %%
# look at records with missing values
df_na= df3[df3.isna().any(axis=1)]
df_na
# Out:
# Empty DataFrame
# Columns: [customer, state, customer_lifetime_value, response, coverage, education, effective_to_date, employmentstatus, gender, income, location_code, marital_status, monthly_premium_auto, months_since_last_claim, months_since_policy_inception, number_of_open_complaints, number_of_policies, policy_type, policy, renew_offer_type, sales_channel, total_claim_amount, vehicle_class, vehicle_size]
# Index: []
#
# [0 rows x 24 columns]

# %%
df_na[['gender', 'state']].value_counts(dropna=False)
# Out:
# Series([], dtype: int64)

# %%
df_na.describe()
# Out:
#        customer_lifetime_value  income  monthly_premium_auto  \
# count                      0.0     0.0                   0.0
# mean                       NaN     NaN                   NaN
# std                        NaN     NaN                   NaN
# min                        NaN     NaN                   NaN
# 25%                        NaN     NaN                   NaN
# 50%                        NaN     NaN                   NaN
# 75%                        NaN     NaN                   NaN
# max                        NaN     NaN                   NaN
#
#        months_since_last_claim  months_since_policy_inception  \
# count                      0.0                            0.0
# mean                       NaN                            NaN
# std                        NaN                            NaN
# min                        NaN                            NaN
# 25%                        NaN                            NaN
# 50%                        NaN                            NaN
# 75%                        NaN                            NaN
# max                        NaN                            NaN
#
#        number_of_open_complaints  number_of_policies  total_claim_amount
# count                        0.0                 0.0                 0.0
# mean                         NaN                 NaN                 NaN
# std                          NaN                 NaN                 NaN
# min                          NaN                 NaN                 NaN
# 25%                          NaN                 NaN                 NaN
# 50%                          NaN                 NaN                 NaN
# 75%                          NaN                 NaN                 NaN
# max                          NaN                 NaN                 NaN

# %%
len(df_na)/len(df3) #percent of missing values in the dataframe
# Out:
# 0.0

# %%
# Remove observations with null values which represents 16% of all observation and look to be random
# We will still have more than 9134 records after deleting missing values
def drop_na(df):
    '''This function drops all missing values in the dataframe.'''
    df = df.dropna()
    return df
df4 = drop_na(df3)

# %%
df4.info()
check_na(df4).sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       9134 non-null   object
#  1   state                          9134 non-null   object
#  2   customer_lifetime_value        9134 non-null   float64
#  3   response                       9134 non-null   object
#  4   coverage                       9134 non-null   object
#  5   education                      9134 non-null   object
#  6   effective_to_date              9134 non-null   object
#  7   employmentstatus               9134 non-null   object
#  8   gender                         9134 non-null   object
#  9   income                         9134 non-null   int64
#  10  location_code                  9134 non-null   object
#  11  marital_status                 9134 non-null   object
#  12  monthly_premium_auto           9134 non-null   int64
#  13  months_since_last_claim        9134 non-null   int64
#  14  months_since_policy_inception  9134 non-null   int64
#  15  number_of_open_complaints      9134 non-null   int64
#  16  number_of_policies             9134 non-null   int64
#  17  policy_type                    9134 non-null   object
#  18  policy                         9134 non-null   object
#  19  renew_offer_type               9134 non-null   object
#  20  sales_channel                  9134 non-null   object
#  21  total_claim_amount             9134 non-null   float64
#  22  vehicle_class                  9134 non-null   object
#  23  vehicle_size                   9134 non-null   object
# dtypes: float64(2), int64(6), object(16)
# memory usage: 1.7+ MB
# 0

# %%
df4.head()
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  BU79786  Washington                  2763.52       No     Basic  Bachelor
# 1  QZ44356     Arizona                  6979.54       No  Extended  Bachelor
# 2  AI49188      Nevada                 12887.43       No   Premium  Bachelor
# 3  WW63253  California                  7645.86       No     Basic  Bachelor
# 4  HB64268  Washington                  2813.69       No     Basic  Bachelor
#
#   effective_to_date employmentstatus gender  income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   months_since_policy_inception number_of_open_complaints  number_of_policies  \
# 0                             5                         0                   1
# 1                            42                         0                   8
# 2                            38                         0                   2
# 3                            65                         0                   7
# 4                            44                         0                   1
#
#       policy_type        policy  renew_offer_type  sales_channel  \
# 0  Corporate Auto  Corporate L3            Offer1          Agent
# 1   Personal Auto   Personal L3            Offer3          Agent
# 2   Personal Auto   Personal L3            Offer1          Agent
# 3  Corporate Auto  Corporate L2            Offer1    Call Center
# 4   Personal Auto   Personal L1            Offer1          Agent
#
#   total_claim_amount  vehicle_class vehicle_size
# 0             384.81   Two-Door Car      Medsize
# 1            1131.46  Four-Door Car      Medsize
# 2             566.47   Two-Door Car      Medsize
# 3             529.88            SUV      Medsize
# 4             138.13  Four-Door Car      Medsize
#
# [5 rows x 24 columns]

# %% [markdown]
# ### 6.1. Datetime format

# %%
def transform_to_date(column):
    column = pd.to_datetime(column, errors='coerce')
    return column
df4.effective_to_date = transform_to_date(df4.effective_to_date)

# %%
df4.sample(10)
# Out:
#      customer       state  customer_lifetime_value response  coverage  \
# 2480  TL59568     Arizona                 12836.01       No   Premium
# 5816  JS76871      Oregon                  8639.09       No     Basic
# 5953  AJ32539      Oregon                  2829.31       No     Basic
# 1340  QZ58370      Nevada                 11820.11       No  Extended
# 7700  JB60515  Washington                  2513.97       No     Basic
# 1369  LO68739     Arizona                  7739.55       No  Extended
# 5956  RH28799     Arizona                  2430.96       No     Basic
# 7159  IQ96928      Oregon                  4348.14       No     Basic
# 8600  QR26617  California                  4865.85       No     Basic
# 1276  QV19964      Oregon                  2599.29       No     Basic
#
#                  education effective_to_date employmentstatus gender  income  \
# 2480  High School or Below        2011-02-28       Unemployed      M       0
# 5816  High School or Below        2011-02-11         Employed      M   62082
# 5953              Bachelor        2011-02-27         Employed      M   25860
# 1340              Bachelor        2011-02-22         Employed      F   86801
# 7700  High School or Below        2011-01-29         Employed      M   50450
# 1369              Bachelor        2011-01-03         Employed      F   64859
# 5956               College        2011-02-23       Unemployed      M       0
# 7159  High School or Below        2011-02-27       Unemployed      F       0
# 8600              Bachelor        2011-02-19         Employed      M   21498
# 1276                Doctor        2011-02-01         Employed      M   33947
#
#       ... months_since_policy_inception number_of_open_complaints  \
# 2480  ...                            28                         0
# 5816  ...                            57                         0
# 5953  ...                            46                         0
# 1340  ...                            20                         0
# 7700  ...                            80                         0
# 1369  ...                            11                         0
# 5956  ...                            30                         0
# 7159  ...                             9                         0
# 8600  ...                            72                         0
# 1276  ...                            48                         1
#
#       number_of_policies     policy_type        policy  renew_offer_type  \
# 2480                   2   Personal Auto   Personal L2            Offer3
# 5816                   2  Corporate Auto  Corporate L3            Offer1
# 5953                   1   Personal Auto   Personal L3            Offer2
# 1340                   2   Personal Auto   Personal L3            Offer4
# 7700                   1   Personal Auto   Personal L3            Offer1
# 1369                   8   Personal Auto   Personal L2            Offer3
# 5956                   1   Personal Auto   Personal L3            Offer2
# 7159                   7  Corporate Auto  Corporate L1            Offer1
# 8600                   9  Corporate Auto  Corporate L1            Offer2
# 1276                   1   Personal Auto   Personal L3            Offer2
#
#       sales_channel total_claim_amount  vehicle_class vehicle_size
# 2480          Agent             835.20   Two-Door Car      Medsize
# 5816          Agent              91.04  Four-Door Car      Medsize
# 5953            Web             345.60  Four-Door Car      Medsize
# 1340         Branch             371.11  Four-Door Car      Medsize
# 7700         Branch             302.40  Four-Door Car      Medsize
# 1369    Call Center             266.95  Four-Door Car      Medsize
# 5956    Call Center             341.33  Four-Door Car      Medsize
# 7159          Agent             675.66  Four-Door Car        Small
# 8600          Agent             302.40  Four-Door Car      Medsize
# 1276            Web             192.21  Four-Door Car      Medsize
#
# [10 rows x 24 columns]

# %% [markdown]
# ### 6.2. Extract the months from the dataset and store in a separate column.

# %%
def extract_month(fromcol):
    '''Extracts month from datetime column. Don't forget to assign function result to a variable with new column name'''
    newcol = fromcol.dt.month
    return newcol
df4['month'] = extract_month(df4.effective_to_date)

# %%
df4.head()
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  BU79786  Washington                  2763.52       No     Basic  Bachelor
# 1  QZ44356     Arizona                  6979.54       No  Extended  Bachelor
# 2  AI49188      Nevada                 12887.43       No   Premium  Bachelor
# 3  WW63253  California                  7645.86       No     Basic  Bachelor
# 4  HB64268  Washington                  2813.69       No     Basic  Bachelor
#
#   effective_to_date employmentstatus gender  income  ...  \
# 0        2011-02-24         Employed      F   56274  ...
# 1        2011-01-31       Unemployed      F       0  ...
# 2        2011-02-19         Employed      F   48767  ...
# 3        2011-01-20       Unemployed      M       0  ...
# 4        2011-02-03         Employed      M   43836  ...
#
#   number_of_open_complaints number_of_policies     policy_type        policy  \
# 0                         0                  1  Corporate Auto  Corporate L3
# 1                         0                  8   Personal Auto   Personal L3
# 2                         0                  2   Personal Auto   Personal L3
# 3                         0                  7  Corporate Auto  Corporate L2
# 4                         0                  1   Personal Auto   Personal L1
#
#    renew_offer_type  sales_channel  total_claim_amount  vehicle_class  \
# 0            Offer1          Agent              384.81   Two-Door Car
# 1            Offer3          Agent             1131.46  Four-Door Car
# 2            Offer1          Agent              566.47   Two-Door Car
# 3            Offer1    Call Center              529.88            SUV
# 4            Offer1          Agent              138.13  Four-Door Car
#
#   vehicle_size month
# 0      Medsize     2
# 1      Medsize     1
# 2      Medsize     2
# 3      Medsize     1
# 4      Medsize     2
#
# [5 rows x 25 columns]

# %% [markdown]
# ### 6.3. Filter the data to show only the information for the first quarter.

# %%
def q1(df):
    '''Filter the dataframe to only the first quarter records(January, February, March)'''
    return df[df['month'].isin({1,2,3})]
df_clean_q1 = q1(df4)
df_clean_q1
# Out:
#      customer       state  customer_lifetime_value response  coverage  \
# 0     BU79786  Washington                  2763.52       No     Basic
# 1     QZ44356     Arizona                  6979.54       No  Extended
# 2     AI49188      Nevada                 12887.43       No   Premium
# 3     WW63253  California                  7645.86       No     Basic
# 4     HB64268  Washington                  2813.69       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California                 23405.99       No     Basic
# 9130  PK87824  California                  3096.51      Yes  Extended
# 9131  TD14365  California                  8163.89       No  Extended
# 9132  UP19263  California                  7524.44       No  Extended
# 9133  Y167826  California                  2611.84       No  Extended
#
#      education effective_to_date employmentstatus gender  income  ...  \
# 0     Bachelor        2011-02-24         Employed      F   56274  ...
# 1     Bachelor        2011-01-31       Unemployed      F       0  ...
# 2     Bachelor        2011-02-19         Employed      F   48767  ...
# 3     Bachelor        2011-01-20       Unemployed      M       0  ...
# 4     Bachelor        2011-02-03         Employed      M   43836  ...
# ...        ...               ...              ...    ...     ...  ...
# 9129  Bachelor        2011-02-10         Employed      M   71941  ...
# 9130   College        2011-02-12         Employed      F   21604  ...
# 9131  Bachelor        2011-02-06       Unemployed      M       0  ...
# 9132   College        2011-02-03         Employed      M   21941  ...
# 9133   College        2011-02-14       Unemployed      M       0  ...
#
#      number_of_open_complaints number_of_policies     policy_type  \
# 0                            0                  1  Corporate Auto
# 1                            0                  8   Personal Auto
# 2                            0                  2   Personal Auto
# 3                            0                  7  Corporate Auto
# 4                            0                  1   Personal Auto
# ...                        ...                ...             ...
# 9129                         0                  2   Personal Auto
# 9130                         0                  1  Corporate Auto
# 9131                         3                  2  Corporate Auto
# 9132                         0                  3   Personal Auto
# 9133                         0                  1  Corporate Auto
#
#             policy  renew_offer_type  sales_channel  total_claim_amount  \
# 0     Corporate L3            Offer1          Agent              384.81
# 1      Personal L3            Offer3          Agent             1131.46
# 2      Personal L3            Offer1          Agent              566.47
# 3     Corporate L2            Offer1    Call Center              529.88
# 4      Personal L1            Offer1          Agent              138.13
# ...            ...               ...            ...                 ...
# 9129   Personal L1            Offer2            Web              198.23
# 9130  Corporate L3            Offer1         Branch              379.20
# 9131  Corporate L2            Offer1         Branch              790.78
# 9132   Personal L2            Offer3         Branch              691.20
# 9133  Corporate L3            Offer4    Call Center              369.60
#
#       vehicle_class vehicle_size month
# 0      Two-Door Car      Medsize     2
# 1     Four-Door Car      Medsize     1
# 2      Two-Door Car      Medsize     2
# 3               SUV      Medsize     1
# 4     Four-Door Car      Medsize     2
# ...             ...          ...   ...
# 9129  Four-Door Car      Medsize     2
# 9130  Four-Door Car      Medsize     2
# 9131  Four-Door Car      Medsize     2
# 9132  Four-Door Car        Large     2
# 9133   Two-Door Car      Medsize     2
#
# [9134 rows x 25 columns]

# %% [markdown]
# # Lab Round 3

# %% [markdown]
# ### 1. Show DataFrame info.

# %%
# copy last df
df_q1 = df_clean_q1
df_q1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9134 entries, 0 to 9133
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       9134 non-null   object
#  1   state                          9134 non-null   object
#  2   customer_lifetime_value        9134 non-null   float64
#  3   response                       9134 non-null   object
#  4   coverage                       9134 non-null   object
#  5   education                      9134 non-null   object
#  6   effective_to_date              9134 non-null   datetime64[ns]
#  7   employmentstatus               9134 non-null   object
#  8   gender                         9134 non-null   object
#  9   income                         9134 non-null   int64
#  10  location_code                  9134 non-null   object
#  11  marital_status                 9134 non-null   object
#  12  monthly_premium_auto           9134 non-null   int64
#  13  months_since_last_claim        9134 non-null   int64
#  14  months_since_policy_inception  9134 non-null   int64
#  15  number_of_open_complaints      9134 non-null   int64
#  16  number_of_policies             9134 non-null   int64
#  17  policy_type                    9134 non-null   object
#  18  policy                         9134 non-null   object
#  19  renew_offer_type               9134 non-null   object
#  20  sales_channel                  9134 non-null   object
#  21  total_claim_amount             9134 non-null   float64
#  22  vehicle_class                  9134 non-null   object
#  23  vehicle_size                   9134 non-null   object
#  24  month                          9134 non-null   int64
# dtypes: datetime64[ns](1), float64(2), int64(7), object(15)
# memory usage: 1.8+ MB

# %%
df_q1.reset_index(drop=True, inplace=True)
df_q1.head()
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  BU79786  Washington                  2763.52       No     Basic  Bachelor
# 1  QZ44356     Arizona                  6979.54       No  Extended  Bachelor
# 2  AI49188      Nevada                 12887.43       No   Premium  Bachelor
# 3  WW63253  California                  7645.86       No     Basic  Bachelor
# 4  HB64268  Washington                  2813.69       No     Basic  Bachelor
#
#   effective_to_date employmentstatus gender  income  ...  \
# 0        2011-02-24         Employed      F   56274  ...
# 1        2011-01-31       Unemployed      F       0  ...
# 2        2011-02-19         Employed      F   48767  ...
# 3        2011-01-20       Unemployed      M       0  ...
# 4        2011-02-03         Employed      M   43836  ...
#
#   number_of_open_complaints number_of_policies     policy_type        policy  \
# 0                         0                  1  Corporate Auto  Corporate L3
# 1                         0                  8   Personal Auto   Personal L3
# 2                         0                  2   Personal Auto   Personal L3
# 3                         0                  7  Corporate Auto  Corporate L2
# 4                         0                  1   Personal Auto   Personal L1
#
#    renew_offer_type  sales_channel  total_claim_amount  vehicle_class  \
# 0            Offer1          Agent              384.81   Two-Door Car
# 1            Offer3          Agent             1131.46  Four-Door Car
# 2            Offer1          Agent              566.47   Two-Door Car
# 3            Offer1    Call Center              529.88            SUV
# 4            Offer1          Agent              138.13  Four-Door Car
#
#   vehicle_size month
# 0      Medsize     2
# 1      Medsize     1
# 2      Medsize     2
# 3      Medsize     1
# 4      Medsize     2
#
# [5 rows x 25 columns]

# %% [markdown]
# ### 2. Describe DataFrame.

# %%
df_q1.describe()
# Out:
#        customer_lifetime_value        income  monthly_premium_auto  \
# count              9134.000000   9134.000000           9134.000000
# mean               8004.940473  37657.380009             93.219291
# std                6870.967599  30379.904734             34.407967
# min                1898.010000      0.000000             61.000000
# 25%                3994.250000      0.000000             68.000000
# 50%                5780.180000  33889.500000             83.000000
# 75%                8962.170000  62320.000000            109.000000
# max               83325.380000  99981.000000            298.000000
#
#        months_since_last_claim  months_since_policy_inception  \
# count              9134.000000                    9134.000000
# mean                 15.097000                      48.064594
# std                  10.073257                      27.905991
# min                   0.000000                       0.000000
# 25%                   6.000000                      24.000000
# 50%                  14.000000                      48.000000
# 75%                  23.000000                      71.000000
# max                  35.000000                      99.000000
#
#        number_of_open_complaints  number_of_policies  total_claim_amount  \
# count                9134.000000         9134.000000         9134.000000
# mean                    0.384388            2.966170          434.088834
# std                     0.910384            2.390182          290.500043
# min                     0.000000            1.000000            0.100000
# 25%                     0.000000            1.000000          272.260000
# 50%                     0.000000            2.000000          383.945000
# 75%                     0.000000            4.000000          547.515000
# max                     5.000000            9.000000         2893.240000
#
#              month
# count  9134.000000
# mean      1.463762
# std       0.498712
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       2.000000
# max       2.000000

# %% [markdown]
# ### 3. Show a plot of the total number of responses.

# %%
response = df_q1['response']
sns.histplot(response)
# Out:
# <AxesSubplot:xlabel='response', ylabel='Count'>

# %%
response.value_counts()
# Out:
# No     7826
# Yes    1308
# Name: response, dtype: int64

# %% [markdown]
# ### 4. Show a plot of the response rate by the sales channel.

# %%
plt.figure(figsize=(15,5))
sns.histplot(data=df_q1, x='sales_channel', hue=response, stat='percent', multiple='dodge')
plt.xlabel('Sales Channel')
plt.title('Percent of Response per Sales Channel')
# Out:
# Text(0.5, 1.0, 'Percent of Response per Sales Channel')

# %% [markdown]
# ### 5. Show a plot of the response rate by the total claim amount.

# %%
# new dfs separating responses to yes and no
no= df_q1[df_q1['response']=='No']
yes= df_q1[df_q1['response']=='Yes']

# %%
fig, axs = plt.subplots(1,2)
plt.figure(figsize=(10,5))
axs[0].hist(no['total_claim_amount'],density=True, bins=20)
axs[0].set_ylim(0, 0.003)
axs[0].title.set_text('No')
axs[1].hist(yes['total_claim_amount'], density=True, bins=20)
axs[1].set_ylim(0, 0.003)
axs[1].title.set_text('Yes')

fig.tight_layout(pad=3.0)

plt.show()

# %%
plt.figure(figsize=(15,10))
sns.boxplot(data=df_q1, x= 'response', y='total_claim_amount',whis=3.5)
# Out:
# <AxesSubplot:xlabel='response', ylabel='total_claim_amount'>

# %% [markdown]
# ### 6. Show a plot of the response rate by income.

# %%
fig, axs = plt.subplots(1,2)
plt.figure(figsize=(20,10))
axs[0].hist(no['income'], bins=15, density=True)
axs[0].title.set_text('No')
axs[1].hist(yes['income'], bins=15, density=True)
axs[1].title.set_text('Yes')

fig.tight_layout(pad=2.0)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.boxplot(data=df_q1, x= 'response', y='income')
# Out:
# <AxesSubplot:xlabel='response', ylabel='income'>
